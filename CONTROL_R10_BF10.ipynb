# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# control experiment

# 10 reps, 100 iterations 
# samples from ONLY WT!

# %%
# all bayexpress results
# 10 replicates
# BF_21 > 10

CONTROL_R10_bayexpress_FC0 = pd.read_csv(f'DGE_results/CONTROL_R10_1_bayexpress.csv').iloc[:,1:2]
CONTROL_R10_bayexpress_FC1 = pd.read_csv(f'DGE_results/CONTROL_R10_1_bayexpress.csv').iloc[:,1:2]
CONTROL_R10_bayexpress_FC2 = pd.read_csv(f'DGE_results/CONTROL_R10_1_bayexpress.csv').iloc[:,1:2]

for i in range(1,101):

    data = pd.read_csv(f'DGE_results/CONTROL_R10_{i}_bayexpress.csv').iloc[:,1:]

    # criteria 0 for significance: (BF_21 > 10) & (abs(FC) > 0)
    CONTROL_R10_bayexpress_FC0[f'{i}'] = (data.BF_21 > 10) & (abs(data.FC) > 0)

    # criteria 1 for significance: (BF_21 > 10) & (abs(FC) > 1)
    CONTROL_R10_bayexpress_FC1[f'{i}'] = (data.BF_21 > 10) & (abs(data.FC) > 1)

    # criteria 2 for significance: (BF_21 > 10) & (abs(FC) > 2)
    CONTROL_R10_bayexpress_FC2[f'{i}'] = (data.BF_21 > 10) & (abs(data.FC) > 2)

CONTROL_R10_bayexpress_FC0['Ntrue'] = [(CONTROL_R10_bayexpress_FC0.iloc[i].value_counts().get(True, 0)) for i in range(len(CONTROL_R10_bayexpress_FC0))]

CONTROL_R10_bayexpress_FC1['Ntrue'] = [(CONTROL_R10_bayexpress_FC1.iloc[i].value_counts().get(True, 0)) for i in range(len(CONTROL_R10_bayexpress_FC1))]

CONTROL_R10_bayexpress_FC2['Ntrue'] = [(CONTROL_R10_bayexpress_FC2.iloc[i].value_counts().get(True, 0)) for i in range(len(CONTROL_R10_bayexpress_FC2))]

display(CONTROL_R10_bayexpress_FC0)
display(CONTROL_R10_bayexpress_FC1)
display(CONTROL_R10_bayexpress_FC2)
# Out:
# /var/folders/dl/6r82c34d3pbdmnyfpk1l0ff00000gn/T/ipykernel_17717/4096341775.py:14: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   CONTROL_R10_bayexpress_FC0[f'{i}'] = (data.BF_21 > 10) & (abs(data.FC) > 0)
# /var/folders/dl/6r82c34d3pbdmnyfpk1l0ff00000gn/T/ipykernel_17717/4096341775.py:17: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   CONTROL_R10_bayexpress_FC1[f'{i}'] = (data.BF_21 > 10) & (abs(data.FC) > 1)
# /var/folders/dl/6r82c34d3pbdmnyfpk1l0ff00000gn/T/ipykernel_17717/4096341775.py:20: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   CONTROL_R10_bayexpress_FC2[f'{i}'] = (data.BF_21 > 10) & (abs(data.FC) > 2)
# /var/folders/dl/6r82c34d3pbdmnyfpk1l0ff00000gn/T/ipykernel_17717/4096341775.py:22: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   CONTROL_R10_bayexpress_FC0['Ntrue'] = [(CONTROL_R10_bayexpress_FC0.iloc[i].value_counts().get(True, 0)) for i in range(len(CONTROL_R10_bayexpress_FC0))]
# /var/folders/dl/6r82c34d3pbdmnyfpk1l0ff00000gn/T/ipykernel_17717/4096341775.py:24: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   CONTROL_R10_bayexpress_FC1['Ntrue'] = [(CONTROL_R10_bayexpress_FC1.iloc[i].value_counts().get(True, 0)) for i in range(len(CONTROL_R10_bayexpress_FC1))]
# /var/folders/dl/6r82c34d3pbdmnyfpk1l0ff00000gn/T/ipykernel_17717/4096341775.py:26: PerformanceWarning: DataFrame is highly fragmented.  This is usually the result of calling `frame.insert` many times, which has poor performance.  Consider joining all columns at once using pd.concat(axis=1) instead. To get a de-fragmented frame, use `newframe = frame.copy()`
#   CONTROL_R10_bayexpress_FC2['Ntrue'] = [(CONTROL_R10_bayexpress_FC2.iloc[i].value_counts().get(True, 0)) for i in range(len(CONTROL_R10_bayexpress_FC2))]
#      locus_name      1      2      3      4      5      6      7      8  \
# 0      15S_rRNA  False  False  False  False  False  False  False  False
# 1      21S_rRNA  False   True  False   True   True  False   True  False
# 2          HRA1  False  False  False  False  False  False  False  False
# 3          ICR1  False  False  False  False  False  False  False  False
# 4          LSR1  False   True  False  False  False  False  False  False
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7121  tY(GUA)J2  False  False  False  False  False  False  False  False
# 7122  tY(GUA)M1  False  False  False  False  False  False  False  False
# 7123  tY(GUA)M2  False  False  False  False  False  False  False  False
# 7124   tY(GUA)O  False  False  False  False  False  False  False  False
# 7125   tY(GUA)Q  False  False  False  False  False  False  False  False
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 0     False  ...  False  False  False  False  False  False  False  False
# 1     False  ...   True   True  False  False  False  False   True  False
# 2     False  ...  False  False  False  False  False  False  False  False
# 3     False  ...  False  False  False  False  False  False  False  False
# 4      True  ...  False   True  False  False  False  False   True  False
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7121  False  ...  False  False  False  False  False  False  False  False
# 7122  False  ...  False  False  False  False  False  False  False  False
# 7123  False  ...  False  False  False  False  False  False  False  False
# 7124  False  ...  False  False  False  False  False  False  False  False
# 7125  False  ...  False  False  False  False  False  False  False  False
#
#         100  Ntrue
# 0     False      4
# 1      True     39
# 2     False      0
# 3     False      0
# 4      True     36
# ...     ...    ...
# 7121  False      0
# 7122  False      0
# 7123  False      0
# 7124  False      0
# 7125  False      0
#
# [7126 rows x 102 columns]
#      locus_name      1      2      3      4      5      6      7      8  \
# 0      15S_rRNA  False  False  False  False  False  False  False  False
# 1      21S_rRNA  False   True  False  False  False  False  False  False
# 2          HRA1  False  False  False  False  False  False  False  False
# 3          ICR1  False  False  False  False  False  False  False  False
# 4          LSR1  False  False  False  False  False  False  False  False
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7121  tY(GUA)J2  False  False  False  False  False  False  False  False
# 7122  tY(GUA)M1  False  False  False  False  False  False  False  False
# 7123  tY(GUA)M2  False  False  False  False  False  False  False  False
# 7124   tY(GUA)O  False  False  False  False  False  False  False  False
# 7125   tY(GUA)Q  False  False  False  False  False  False  False  False
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 0     False  ...  False  False  False  False  False  False  False  False
# 1     False  ...  False   True  False  False  False  False  False  False
# 2     False  ...  False  False  False  False  False  False  False  False
# 3     False  ...  False  False  False  False  False  False  False  False
# 4     False  ...  False  False  False  False  False  False  False  False
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7121  False  ...  False  False  False  False  False  False  False  False
# 7122  False  ...  False  False  False  False  False  False  False  False
# 7123  False  ...  False  False  False  False  False  False  False  False
# 7124  False  ...  False  False  False  False  False  False  False  False
# 7125  False  ...  False  False  False  False  False  False  False  False
#
#         100  Ntrue
# 0     False      4
# 1     False     10
# 2     False      0
# 3     False      0
# 4     False      1
# ...     ...    ...
# 7121  False      0
# 7122  False      0
# 7123  False      0
# 7124  False      0
# 7125  False      0
#
# [7126 rows x 102 columns]
#      locus_name      1      2      3      4      5      6      7      8  \
# 0      15S_rRNA  False  False  False  False  False  False  False  False
# 1      21S_rRNA  False  False  False  False  False  False  False  False
# 2          HRA1  False  False  False  False  False  False  False  False
# 3          ICR1  False  False  False  False  False  False  False  False
# 4          LSR1  False  False  False  False  False  False  False  False
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7121  tY(GUA)J2  False  False  False  False  False  False  False  False
# 7122  tY(GUA)M1  False  False  False  False  False  False  False  False
# 7123  tY(GUA)M2  False  False  False  False  False  False  False  False
# 7124   tY(GUA)O  False  False  False  False  False  False  False  False
# 7125   tY(GUA)Q  False  False  False  False  False  False  False  False
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 0     False  ...  False  False  False  False  False  False  False  False
# 1     False  ...  False  False  False  False  False  False  False  False
# 2     False  ...  False  False  False  False  False  False  False  False
# 3     False  ...  False  False  False  False  False  False  False  False
# 4     False  ...  False  False  False  False  False  False  False  False
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 7121  False  ...  False  False  False  False  False  False  False  False
# 7122  False  ...  False  False  False  False  False  False  False  False
# 7123  False  ...  False  False  False  False  False  False  False  False
# 7124  False  ...  False  False  False  False  False  False  False  False
# 7125  False  ...  False  False  False  False  False  False  False  False
#
#         100  Ntrue
# 0     False      0
# 1     False      0
# 2     False      0
# 3     False      0
# 4     False      0
# ...     ...    ...
# 7121  False      0
# 7122  False      0
# 7123  False      0
# 7124  False      0
# 7125  False      0
#
# [7126 rows x 102 columns]

# %%
# Set global font size to 12
plt.rcParams.update({'font.size': 12})

fig, axs = plt.subplots(1, 1, sharey=True, figsize=(6, 4), dpi=300)

# scatters
axs.scatter(np.arange(1, 101),
            CONTROL_R10_bayexpress_FC0.iloc[:, 1:-1].sum(axis=0),
            c='#332288', s=30,
            label=f'BF_21 > 1, FC > 0, total = {sum(CONTROL_R10_bayexpress_FC0.iloc[:,1:-1].sum(axis=0))}',
            alpha=0.9, marker='x')

axs.scatter(np.arange(1, 101),
            CONTROL_R10_bayexpress_FC1.iloc[:, 1:-1].sum(axis=0),
            c='#44AA99', s=30,
            label=f'BF_21 > 1, FC > 1, total = {sum(CONTROL_R10_bayexpress_FC1.iloc[:,1:-1].sum(axis=0))}',
            alpha=0.9, marker='x')

axs.scatter(np.arange(1, 101),
            CONTROL_R10_bayexpress_FC2.iloc[:, 1:-1].sum(axis=0),
            c='#CC6677', s=30,
            label=f'BF_21 > 1, FC > 2, total = {sum(CONTROL_R10_bayexpress_FC2.iloc[:,1:-1].sum(axis=0))}',
            alpha=0.9, marker='x')

axs.legend(loc='upper left')

# Use tex in labels
axs.set_xticks(np.arange(1, 101))
axs.set_xticklabels('')

# formatting y axis ticks
plt.gca().ticklabel_format(axis='y', style='plain', useOffset=False)

axs.set_xlabel('100 iterations')
axs.set_ylabel('# putative DEGs')

# Set y limit 3500
axs.set_ylim(-100, 3500)

plt.show()

# %%
# zoom in 

# Set global font size to 12
plt.rcParams.update({'font.size': 12})

fig, axs = plt.subplots(1, 1, sharey=True, figsize=(6, 4), dpi=300)


# scatters
axs.scatter(np.arange(1, 101),
            CONTROL_R10_bayexpress_FC0.iloc[:, 1:-1].sum(axis=0),
            c='#332288', s=30,
            label=f'BF_21 > 1, FC > 0, total = {sum(CONTROL_R10_bayexpress_FC0.iloc[:,1:-1].sum(axis=0))}',
            alpha=0.9, marker='x')

axs.scatter(np.arange(1, 101),
            CONTROL_R10_bayexpress_FC1.iloc[:, 1:-1].sum(axis=0),
            c='#44AA99', s=30,
            label=f'BF_21 > 1, FC > 1, total = {sum(CONTROL_R10_bayexpress_FC1.iloc[:,1:-1].sum(axis=0))}',
            alpha=0.9, marker='x')

axs.scatter(np.arange(1, 101),
            CONTROL_R10_bayexpress_FC2.iloc[:, 1:-1].sum(axis=0),
            c='#CC6677', s=30,
            label=f'BF_21 > 1, FC > 2, total = {sum(CONTROL_R10_bayexpress_FC2.iloc[:,1:-1].sum(axis=0))}',
            alpha=0.9, marker='x')

axs.legend(loc='upper left')

# Use tex in labels
axs.set_xticks(np.arange(1, 101))
axs.set_xticklabels('')

# formatting y axis ticks
plt.gca().ticklabel_format(axis='y', style='plain', useOffset=False)

# Set axis labels
axs.set_xlabel('100 iterations')  # Font size is now 12 by default
axs.set_ylabel('# putative DEGs')  # Font size is now 12 by default

# Set y limit 3500
axs.set_ylim(-10, 300)

plt.show()

# %%
# just a different visualisation

# Set global font size to 12
plt.rcParams.update({'font.size': 12})

fig, axs = plt.subplots(1,1,sharey=True, figsize=(6,4), dpi=300)


series = CONTROL_R10_bayexpress_FC0.iloc[:,1:-1].sum(axis=0)
series.plot(kind='line', color='#332288', alpha=0.8, ylim=[-5,500], linewidth=2, label=f'BF_21 > 1, FC > 0, total = {sum(CONTROL_R10_bayexpress_FC0.iloc[:,1:-1].sum(axis=0))}')

series = CONTROL_R10_bayexpress_FC1.iloc[:,1:-1].sum(axis=0)
series.plot(kind='line', color='#44AA99', alpha=0.8, ylim=[-5,500], linewidth=2, label=f'BF_21 > 1, FC > 1, total = {sum(CONTROL_R10_bayexpress_FC1.iloc[:,1:-1].sum(axis=0))}')

series = CONTROL_R10_bayexpress_FC2.iloc[:,1:-1].sum(axis=0)
series.plot(kind='line', color='#CC6677', alpha=0.8, ylim=[-5,500], linewidth=2, label=f'BF_21 > 1, FC > 2, total = {sum(CONTROL_R10_bayexpress_FC2.iloc[:,1:-1].sum(axis=0))}')

axs.set_xlabel('Iterations')
axs.set_ylabel('# putative DEGs')

axs.set_xticks([1,100])
axs.set_xticklabels(['1', '100'])

axs.legend(loc='center left')

plt.show()

# %%
# R10 means number of replicates in 100 bootstrapping iterations is 10
# FC > 0
# got hits (any)

# let's find out which genes we found to produce hits in the control and see if we can identify them with Bayes factors for consistency

print('Find genes that got hits in the control experiment')
display(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 0])

# importing results from differential gene expression anaylsis to check what they are
RALL_bayexpress = pd.read_csv('RALL_bayexpress.csv', index_col=0)

print('All replicates, bayexpress results')
display(RALL_bayexpress)

print('Display only the genes that got hits in the control experiment')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 0].index)])

print('Display only the genes that got hits in the control experiment + where identified with bayes factors for consistency of replicates in the WT')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 0].index)].loc[(RALL_bayexpress.BF_k1_WT > 1)])

print('Display only the genes that got hits in the control experiment + where NOT identified with bayes factors for consistency of replicates in the WT')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 0].index)].loc[(RALL_bayexpress.BF_k1_WT < 1)])

print('Among the genes that produced 0 hits, where there any genes that would be identified as variable by BF_k1 > 1?')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue == 0].index)].loc[(RALL_bayexpress.BF_k1_WT > 1)])
# Out:
# Find genes that got hits in the control experiment
#      locus_name      1      2      3      4      5      6      7      8  \
# 0      15S_rRNA  False  False  False  False  False  False  False  False
# 1      21S_rRNA  False   True  False   True   True  False   True  False
# 4          LSR1  False   True  False  False  False  False  False  False
# 41       RDN5-1  False   True  False  False  False   True  False  False
# 46       RDN5-6  False   True  False  False  False   True  False  False
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6777      snR44  False  False  False  False  False   True  False  False
# 6782      snR49  False  False  False  False  False   True  False  False
# 6807      snR70  False  False  False  False  False  False  False  False
# 6821      snR83  False  False  False  False  False   True  False  False
# 6824      snR86  False  False  False  False  False   True   True  False
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 0     False  ...  False  False  False  False  False  False  False  False
# 1     False  ...   True   True  False  False  False  False   True  False
# 4      True  ...  False   True  False  False  False  False   True  False
# 41    False  ...  False   True  False  False  False  False  False  False
# 46    False  ...  False   True  False  False  False  False  False  False
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6777  False  ...  False  False  False  False  False  False   True  False
# 6782  False  ...  False  False  False  False  False  False  False  False
# 6807  False  ...  False  False  False  False  False  False  False  False
# 6821  False  ...  False  False  False  False  False  False   True  False
# 6824  False  ...  False  False  False  False  False  False   True  False
#
#         100  Ntrue
# 0     False      4
# 1      True     39
# 4      True     36
# 41     True     26
# 46     True     26
# ...     ...    ...
# 6777  False      7
# 6782  False      1
# 6807  False      1
# 6821  False      6
# 6824  False     20
#
# [3286 rows x 102 columns]
# All replicates, bayexpress results
#      locus_name      BF_21        FC    BF_k1_WT  CIG_WT   BF_k1_Snf2  \
# 0      15S_rRNA  -3.710645  0.274047 -107.138056   False    53.627445
# 1      21S_rRNA  -1.302642  0.147177  362.115507    True  1052.203968
# 2          HRA1  -5.206545 -0.564787 -240.338654   False  -258.581365
# 3          ICR1  76.746125  0.504048 -194.077441   False  -196.467262
# 4          LSR1   0.451012  0.120243  251.787125    True   478.066414
# ...         ...        ...       ...         ...     ...          ...
# 7121  tY(GUA)J2  -7.312143  0.861839 -270.299503   False  -281.214963
# 7122  tY(GUA)M1  -7.406574  0.022303 -262.736078   False  -275.253246
# 7123  tY(GUA)M2  -7.727890  0.183767 -271.177492   False  -284.863866
# 7124   tY(GUA)O  -7.622253  0.347266 -270.291196   False  -282.682788
# 7125   tY(GUA)Q  -8.273720 -0.138161 -275.349735   False  -289.991744
#
#       CIG_Snf2
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
# ...        ...
# 7121     False
# 7122     False
# 7123     False
# 7124     False
# 7125     False
#
# [7126 rows x 7 columns]
# Display only the genes that got hits in the control experiment
#      locus_name       BF_21        FC    BF_k1_WT  CIG_WT   BF_k1_Snf2  \
# 0      15S_rRNA   -3.710645  0.274047 -107.138056   False    53.627445
# 1      21S_rRNA   -1.302642  0.147177  362.115507    True  1052.203968
# 4          LSR1    0.451012  0.120243  251.787125    True   478.066414
# 41       RDN5-1   13.774601  0.316040  246.914584    True   521.186933
# 46       RDN5-6   15.230943  0.469612  172.850686    True   347.304031
# ...         ...         ...       ...         ...     ...          ...
# 6777      snR44   44.784503 -0.377448  -69.135666   False  -160.634165
# 6782      snR49    3.810074 -0.194770 -128.891351   False  -181.780529
# 6807      snR70   50.106839  0.523481 -171.219260   False  -175.092799
# 6821      snR83   -5.961317 -0.049198  -97.702962   False  -164.859374
# 6824      snR86  272.275536  0.372995  120.984196    True   160.053022
#
#       CIG_Snf2
# 0         True
# 1         True
# 4         True
# 41        True
# 46        True
# ...        ...
# 6777     False
# 6782     False
# 6807     False
# 6821     False
# 6824      True
#
# [3286 rows x 7 columns]
# Display only the genes that got hits in the control experiment + where identified with bayes factors for consistency of replicates in the WT
#      locus_name       BF_21        FC    BF_k1_WT  CIG_WT   BF_k1_Snf2  \
# 1      21S_rRNA   -1.302642  0.147177  362.115507    True  1052.203968
# 4          LSR1    0.451012  0.120243  251.787125    True   478.066414
# 41       RDN5-1   13.774601  0.316040  246.914584    True   521.186933
# 46       RDN5-6   15.230943  0.469612  172.850686    True   347.304031
# 56       RUF5-1   -1.191579  0.080133  232.720615    True     4.230186
# ...         ...         ...       ...         ...     ...          ...
# 6730    YPR190C   48.045047 -0.216275  135.716958    True  -136.905959
# 6731    YPR191W  218.989419  0.279871  251.986788    True   -38.705868
# 6752     snR17a    7.383833  0.329308   28.421292    True   239.879652
# 6761      snR30   20.556922  0.159709    2.616569    True    85.355966
# 6824      snR86  272.275536  0.372995  120.984196    True   160.053022
#
#       CIG_Snf2
# 1         True
# 4         True
# 41        True
# 46        True
# 56        True
# ...        ...
# 6730     False
# 6731     False
# 6752      True
# 6761      True
# 6824      True
#
# [1602 rows x 7 columns]
# Display only the genes that got hits in the control experiment + where NOT identified with bayes factors for consistency of replicates in the WT
#      locus_name       BF_21        FC    BF_k1_WT  CIG_WT  BF_k1_Snf2  \
# 0      15S_rRNA   -3.710645  0.274047 -107.138056   False   53.627445
# 51         RPR1  102.505781 -0.973507  -29.530821   False -163.636890
# 52        RUF20   58.301953  0.467352  -87.667016   False -105.505837
# 53        RUF21   24.026871  0.572910  -40.011620   False  -18.211398
# 61      YAL001C  510.650373  0.634130  -70.980470   False  -69.042919
# ...         ...         ...       ...         ...     ...         ...
# 6768      snR37    2.932227 -0.229684  -57.966295   False  -50.162245
# 6777      snR44   44.784503 -0.377448  -69.135666   False -160.634165
# 6782      snR49    3.810074 -0.194770 -128.891351   False -181.780529
# 6807      snR70   50.106839  0.523481 -171.219260   False -175.092799
# 6821      snR83   -5.961317 -0.049198  -97.702962   False -164.859374
#
#       CIG_Snf2
# 0         True
# 51       False
# 52       False
# 53       False
# 61       False
# ...        ...
# 6768     False
# 6777     False
# 6782     False
# 6807     False
# 6821     False
#
# [1684 rows x 7 columns]
# Among the genes that produced 0 hits, where there any genes that would be identified as variable by BF_k1 > 1?
# Empty DataFrame
# Columns: [locus_name, BF_21, FC, BF_k1_WT, CIG_WT, BF_k1_Snf2, CIG_Snf2]
# Index: []

# %%
# R10 means number of replicates in 100 bootstrapping iterations is 10
# FC > 0
# got more than 10 hits

# let's find out which genes we found to produce hits in the control and see if we can identify them with Bayes factors for consistency

print('Find genes that got more than 10 hits in the control experiment')
display(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 10])

# importing results from differential gene expression anaylsis to check what they are
RALL_bayexpress = pd.read_csv('RALL_bayexpress.csv', index_col=0)

print('All replicates, bayexpress results')
display(RALL_bayexpress)

print('Display only the genes that got more than 10 hits in the control experiment')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 10].index)])

print('Display only the genes that got more than 10 hits in the control experiment + where identified with bayes factors for consistency of replicates in the WT')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 10].index)].loc[(RALL_bayexpress.BF_k1_WT > 1)])

print('Display only the genes that got more than 10 hits in the control experiment + where NOT identified with bayes factors for consistency of replicates in the WT')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 10].index)].loc[(RALL_bayexpress.BF_k1_WT < 1)])
# Out:
# Find genes that got more than 10 hits in the control experiment
#      locus_name      1      2      3      4      5      6      7      8  \
# 1      21S_rRNA  False   True  False   True   True  False   True  False
# 4          LSR1  False   True  False  False  False  False  False  False
# 41       RDN5-1  False   True  False  False  False   True  False  False
# 46       RDN5-6  False   True  False  False  False   True  False  False
# 53        RUF21  False  False  False  False   True   True  False  False
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6731    YPR191W  False  False  False  False  False  False   True  False
# 6745    YPR204W  False  False   True  False  False   True  False   True
# 6752     snR17a  False   True  False  False  False  False  False  False
# 6757     snR190  False  False  False  False  False  False  False  False
# 6824      snR86  False  False  False  False  False   True   True  False
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 1     False  ...   True   True  False  False  False  False   True  False
# 4      True  ...  False   True  False  False  False  False   True  False
# 41    False  ...  False   True  False  False  False  False  False  False
# 46    False  ...  False   True  False  False  False  False  False  False
# 53    False  ...  False   True  False  False  False  False   True   True
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6731  False  ...  False  False  False  False  False   True  False  False
# 6745  False  ...  False  False  False  False  False  False  False  False
# 6752   True  ...  False   True  False  False  False  False   True  False
# 6757   True  ...  False   True  False  False  False  False  False  False
# 6824  False  ...  False  False  False  False  False  False   True  False
#
#         100  Ntrue
# 1      True     39
# 4      True     36
# 41     True     26
# 46     True     26
# 53    False     13
# ...     ...    ...
# 6731   True     25
# 6745  False     14
# 6752   True     18
# 6757   True     12
# 6824  False     20
#
# [1525 rows x 102 columns]
# All replicates, bayexpress results
#      locus_name      BF_21        FC    BF_k1_WT  CIG_WT   BF_k1_Snf2  \
# 0      15S_rRNA  -3.710645  0.274047 -107.138056   False    53.627445
# 1      21S_rRNA  -1.302642  0.147177  362.115507    True  1052.203968
# 2          HRA1  -5.206545 -0.564787 -240.338654   False  -258.581365
# 3          ICR1  76.746125  0.504048 -194.077441   False  -196.467262
# 4          LSR1   0.451012  0.120243  251.787125    True   478.066414
# ...         ...        ...       ...         ...     ...          ...
# 7121  tY(GUA)J2  -7.312143  0.861839 -270.299503   False  -281.214963
# 7122  tY(GUA)M1  -7.406574  0.022303 -262.736078   False  -275.253246
# 7123  tY(GUA)M2  -7.727890  0.183767 -271.177492   False  -284.863866
# 7124   tY(GUA)O  -7.622253  0.347266 -270.291196   False  -282.682788
# 7125   tY(GUA)Q  -8.273720 -0.138161 -275.349735   False  -289.991744
#
#       CIG_Snf2
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
# ...        ...
# 7121     False
# 7122     False
# 7123     False
# 7124     False
# 7125     False
#
# [7126 rows x 7 columns]
# Display only the genes that got more than 10 hits in the control experiment
#      locus_name       BF_21        FC    BF_k1_WT  CIG_WT   BF_k1_Snf2  \
# 1      21S_rRNA   -1.302642  0.147177  362.115507    True  1052.203968
# 4          LSR1    0.451012  0.120243  251.787125    True   478.066414
# 41       RDN5-1   13.774601  0.316040  246.914584    True   521.186933
# 46       RDN5-6   15.230943  0.469612  172.850686    True   347.304031
# 53        RUF21   24.026871  0.572910  -40.011620   False   -18.211398
# ...         ...         ...       ...         ...     ...          ...
# 6731    YPR191W  218.989419  0.279871  251.986788    True   -38.705868
# 6745    YPR204W  814.266672  0.541523   -1.746145    True    37.268866
# 6752     snR17a    7.383833  0.329308   28.421292    True   239.879652
# 6757     snR190   -6.562044 -0.001634  -49.290008   False   -63.762229
# 6824      snR86  272.275536  0.372995  120.984196    True   160.053022
#
#       CIG_Snf2
# 1         True
# 4         True
# 41        True
# 46        True
# 53       False
# ...        ...
# 6731     False
# 6745      True
# 6752      True
# 6757     False
# 6824      True
#
# [1525 rows x 7 columns]
# Display only the genes that got more than 10 hits in the control experiment + where identified with bayes factors for consistency of replicates in the WT
#      locus_name       BF_21        FC    BF_k1_WT  CIG_WT   BF_k1_Snf2  \
# 1      21S_rRNA   -1.302642  0.147177  362.115507    True  1052.203968
# 4          LSR1    0.451012  0.120243  251.787125    True   478.066414
# 41       RDN5-1   13.774601  0.316040  246.914584    True   521.186933
# 46       RDN5-6   15.230943  0.469612  172.850686    True   347.304031
# 56       RUF5-1   -1.191579  0.080133  232.720615    True     4.230186
# ...         ...         ...       ...         ...     ...          ...
# 6727    YPR187W   39.001492 -0.117950  100.066660    True  -108.538938
# 6730    YPR190C   48.045047 -0.216275  135.716958    True  -136.905959
# 6731    YPR191W  218.989419  0.279871  251.986788    True   -38.705868
# 6752     snR17a    7.383833  0.329308   28.421292    True   239.879652
# 6824      snR86  272.275536  0.372995  120.984196    True   160.053022
#
#       CIG_Snf2
# 1         True
# 4         True
# 41        True
# 46        True
# 56        True
# ...        ...
# 6727     False
# 6730     False
# 6731     False
# 6752      True
# 6824      True
#
# [1457 rows x 7 columns]
# Display only the genes that got more than 10 hits in the control experiment + where NOT identified with bayes factors for consistency of replicates in the WT
#      locus_name        BF_21        FC   BF_k1_WT  CIG_WT  BF_k1_Snf2  \
# 53        RUF21    24.026871  0.572910 -40.011620   False  -18.211398
# 103   YAL037C-A     1.234011 -0.338439 -16.174943   False -127.606812
# 211     YBL026W    76.856290  0.281821 -60.714558   False -103.152154
# 489     YBR162C  5986.100458  0.547220 -11.212930   False   42.095771
# 549     YBR215W   161.651123  0.400619  -6.054872   False  -76.262040
# ...         ...          ...       ...        ...     ...         ...
# 6474    YPL242C   209.314218  0.408458 -24.378333   False   39.478586
# 6547    YPR023C  1970.133813  0.799128  -8.107800   False   14.670405
# 6562    YPR037C   117.783455  0.268815  -4.448602   False   25.339151
# 6745    YPR204W   814.266672  0.541523  -1.746145    True   37.268866
# 6757     snR190    -6.562044 -0.001634 -49.290008   False  -63.762229
#
#       CIG_Snf2
# 53       False
# 103      False
# 211      False
# 489       True
# 549      False
# ...        ...
# 6474      True
# 6547      True
# 6562      True
# 6745      True
# 6757     False
#
# [68 rows x 7 columns]

# %%
# R10 means number of replicates in 100 bootstrapping iterations is 10
# FC > 1
# got hits (any)

# let's find out which genes we found to produce hits in the control and see if we can identify them with Bayes factors for consistency

print('Find genes that got hits in the control experiment')
display(CONTROL_R10_bayexpress_FC1.loc[CONTROL_R10_bayexpress_FC1.Ntrue > 0])

# importing results from differential gene expression anaylsis to check what they are
RALL_bayexpress = pd.read_csv('RALL_bayexpress.csv', index_col=0)

print('All replicates, bayexpress results')
display(RALL_bayexpress)

print('Display only the genes that got hits in the control experiment')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC1.loc[CONTROL_R10_bayexpress_FC1.Ntrue > 0].index)])

print('Display only the genes that got hits in the control experiment + where identified with bayes factors for consistency of replicates in the WT')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC1.loc[CONTROL_R10_bayexpress_FC1.Ntrue > 0].index)].loc[(RALL_bayexpress.BF_k1_WT > 1)])

print('Display only the genes that got hits in the control experiment + where NOT identified with bayes factors for consistency of replicates in the WT')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC1.loc[CONTROL_R10_bayexpress_FC1.Ntrue > 0].index)].loc[(RALL_bayexpress.BF_k1_WT < 1)])

print('Among the genes that produced 0 hits, where there any genes that would be identified as variable by BF_k1 > 1?')
display(RALL_bayexpress.iloc[(CONTROL_R10_bayexpress_FC1.loc[CONTROL_R10_bayexpress_FC1.Ntrue == 0].index)].loc[(RALL_bayexpress.BF_k1_WT > 1)])
# Out:
# Find genes that got hits in the control experiment
#      locus_name      1      2      3      4      5      6      7      8  \
# 0      15S_rRNA  False  False  False  False  False  False  False  False
# 1      21S_rRNA  False   True  False  False  False  False  False  False
# 4          LSR1  False  False  False  False  False  False  False  False
# 41       RDN5-1  False   True  False  False  False  False  False  False
# 46       RDN5-6  False   True  False  False  False   True  False  False
# 53        RUF21  False  False  False  False   True   True  False  False
# 58         SCR1  False   True  False  False  False   True  False  False
# 89    YAL026C-A  False  False  False  False  False  False  False  False
# 103   YAL037C-A  False  False  False  False   True   True  False  False
# 104   YAL037C-B  False  False  False  False  False  False  False  False
# 269     YBL077W  False  False  False  False  False  False  False  False
# 519     YBR190W  False  False  False  False  False  False  False  False
# 521   YBR191W-A  False  False  False  False   True   True  False  False
# 740     YCR021C  False  False  False  False  False  False  False  False
# 996     YDL158C  False  False  False  False  False  False  False  False
# 1070    YDL228C  False  False  False  False  False  False  False  False
# 1236    YDR133C  False  False  False  False  False  False  False  False
# 1290  YDR183C-A  False  False  False  False  False  False  False  False
# 1538  YDR406W-A  False  False  False  False  False  False  False  False
# 1637    YDR504C  False  False  False  False  False   True  False  False
# 1657    YDR523C  False  False  False  False  False  False  False  False
# 1661  YDR524W-C  False  False  False  False  False   True  False  False
# 1725    YEL033W  False  False  False  False  False  False  False  False
# 1893    YER091C  False  False  False  False  False  False  False  False
# 2125    YFR032C  False  False  False  False  False  False  False  False
# 2149  YFR052C-A  False  False  False  False  False  False  False  False
# 2345    YGL184C  False  False  False  False   True  False  False   True
# 2453    YGR025W  False  False  False  False  False  False  False  False
# 2581    YGR142W  False  False  False  False  False   True  False  False
# 4049    YKR080W  False  False  False  False  False  False  False  False
# 4212    YLR062C  False  False  False  False  False  False  False  False
# 4226    YLR076C  False  False  False  False  False  False  False  False
# 4314  YLR154W-E  False   True  False  False  False  False  False  False
# 4315  YLR154W-F  False  False  False  False  False  False  False  False
# 4330    YLR162W  False   True  False  False  False   True  False  False
# 4331  YLR162W-A  False   True  False  False  False  False  False  False
# 4525  YLR342W-A  False  False  False  False   True   True  False  False
# 5496    YNL303W  False  False  False  False  False   True  False  False
# 5980    YOR169C  False  False  False  False  False   True  False  False
# 6127    YOR309C  False  False  False  False  False   True  False  False
# 6357    YPL130W  False  False  False  False  False  False  False  False
# 6370    YPL142C  False  False  False  False  False  False  False  False
# 6569    YPR044C  False  False  False  False  False  False  False  False
# 6752     snR17a  False   True  False  False  False  False  False  False
# 6757     snR190  False  False  False  False  False  False  False  False
# 6821      snR83  False  False  False  False  False  False  False  False
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 0     False  ...  False  False  False  False  False  False  False  False
# 1     False  ...  False   True  False  False  False  False  False  False
# 4     False  ...  False  False  False  False  False  False  False  False
# 41    False  ...  False   True  False  False  False  False  False  False
# 46    False  ...  False   True  False  False  False  False  False  False
# 53    False  ...  False   True  False  False  False  False  False  False
# 58    False  ...  False   True  False  False  False  False  False  False
# 89    False  ...  False  False  False  False  False  False  False  False
# 103    True  ...  False  False  False  False  False  False  False   True
# 104   False  ...  False  False  False  False  False  False  False  False
# 269   False  ...  False  False  False  False  False  False  False  False
# 519   False  ...  False  False  False  False  False  False  False  False
# 521   False  ...  False  False  False  False  False  False  False  False
# 740   False  ...  False  False  False  False  False  False  False  False
# 996   False  ...  False  False  False  False  False  False  False  False
# 1070  False  ...  False  False  False  False  False  False  False  False
# 1236  False  ...  False  False  False  False  False  False  False  False
# 1290  False  ...  False  False  False  False  False  False  False  False
# 1538  False  ...  False  False  False  False  False  False  False  False
# 1637  False  ...  False  False  False  False  False  False  False  False
# 1657  False  ...  False  False  False  False  False  False  False  False
# 1661  False  ...  False  False  False  False  False  False  False  False
# 1725  False  ...  False  False  False  False  False  False  False  False
# 1893  False  ...  False  False  False  False  False  False  False  False
# 2125  False  ...  False  False  False  False  False  False  False  False
# 2149  False  ...  False  False  False  False  False  False  False  False
# 2345  False  ...   True  False  False  False  False  False  False  False
# 2453  False  ...  False  False  False  False  False  False  False  False
# 2581  False  ...  False  False  False  False  False  False  False  False
# 4049  False  ...  False  False  False  False  False  False  False  False
# 4212  False  ...  False  False  False  False  False  False  False  False
# 4226  False  ...  False  False  False  False  False  False  False  False
# 4314  False  ...  False  False  False  False  False  False  False  False
# 4315  False  ...  False  False  False  False  False  False  False  False
# 4330  False  ...  False   True  False  False  False  False  False  False
# 4331  False  ...  False   True  False  False  False  False  False  False
# 4525  False  ...  False  False  False  False  False  False  False  False
# 5496  False  ...  False   True  False  False  False  False  False  False
# 5980  False  ...  False  False  False  False  False  False  False  False
# 6127  False  ...  False  False  False  False  False  False  False  False
# 6357  False  ...  False  False  False  False  False  False  False  False
# 6370  False  ...  False  False  False  False  False  False  False  False
# 6569  False  ...  False  False  False  False  False  False  False  False
# 6752  False  ...  False   True  False  False  False  False   True  False
# 6757   True  ...  False   True  False  False  False  False  False  False
# 6821  False  ...  False  False  False  False  False  False  False  False
#
#         100  Ntrue
# 0     False      4
# 1     False     10
# 4     False      1
# 41    False     13
# 46     True     24
# 53    False      9
# 58     True     19
# 89    False      1
# 103   False     13
# 104   False      1
# 269   False      1
# 519   False      1
# 521   False     10
# 740   False      1
# 996   False      1
# 1070  False      1
# 1236  False      1
# 1290  False      1
# 1538  False      2
# 1637  False      4
# 1657  False      1
# 1661  False      3
# 1725  False      2
# 1893  False      2
# 2125  False      1
# 2149  False      2
# 2345   True     35
# 2453  False      1
# 2581  False      1
# 4049  False      2
# 4212  False      2
# 4226  False      1
# 4314  False      4
# 4315  False      5
# 4330   True     16
# 4331   True     13
# 4525  False      5
# 5496  False      7
# 5980  False      4
# 6127  False      2
# 6357  False      1
# 6370  False      4
# 6569  False      4
# 6752   True      5
# 6757   True     12
# 6821  False      1
#
# [46 rows x 102 columns]
# All replicates, bayexpress results
#      locus_name      BF_21        FC    BF_k1_WT  CIG_WT   BF_k1_Snf2  \
# 0      15S_rRNA  -3.710645  0.274047 -107.138056   False    53.627445
# 1      21S_rRNA  -1.302642  0.147177  362.115507    True  1052.203968
# 2          HRA1  -5.206545 -0.564787 -240.338654   False  -258.581365
# 3          ICR1  76.746125  0.504048 -194.077441   False  -196.467262
# 4          LSR1   0.451012  0.120243  251.787125    True   478.066414
# ...         ...        ...       ...         ...     ...          ...
# 7121  tY(GUA)J2  -7.312143  0.861839 -270.299503   False  -281.214963
# 7122  tY(GUA)M1  -7.406574  0.022303 -262.736078   False  -275.253246
# 7123  tY(GUA)M2  -7.727890  0.183767 -271.177492   False  -284.863866
# 7124   tY(GUA)O  -7.622253  0.347266 -270.291196   False  -282.682788
# 7125   tY(GUA)Q  -8.273720 -0.138161 -275.349735   False  -289.991744
#
#       CIG_Snf2
# 0         True
# 1         True
# 2        False
# 3        False
# 4         True
# ...        ...
# 7121     False
# 7122     False
# 7123     False
# 7124     False
# 7125     False
#
# [7126 rows x 7 columns]
# Display only the genes that got hits in the control experiment
#      locus_name         BF_21        FC      BF_k1_WT  CIG_WT   BF_k1_Snf2  \
# 0      15S_rRNA     -3.710645  0.274047   -107.138056   False    53.627445
# 1      21S_rRNA     -1.302642  0.147177    362.115507    True  1052.203968
# 4          LSR1      0.451012  0.120243    251.787125    True   478.066414
# 41       RDN5-1     13.774601  0.316040    246.914584    True   521.186933
# 46       RDN5-6     15.230943  0.469612    172.850686    True   347.304031
# 53        RUF21     24.026871  0.572910    -40.011620   False   -18.211398
# 58         SCR1     10.530223  0.125605   3463.535578    True  5939.249536
# 89    YAL026C-A     34.843922  0.889168   -177.688653   False  -174.081566
# 103   YAL037C-A      1.234011 -0.338439    -16.174943   False  -127.606812
# 104   YAL037C-B     -0.026307 -0.114575    402.523899    True   305.562530
# 269     YBL077W      8.840953  0.374675   -138.677913   False  -165.974434
# 519     YBR190W     -6.162852  0.068453   -127.176368   False  -127.193474
# 521   YBR191W-A     -2.073965  0.242930    -41.687820   False   -37.177753
# 740     YCR021C   6285.979055 -2.312448   3075.033017    True  -200.094307
# 996     YDL158C     63.381742  0.722901   -134.671667   False  -110.514422
# 1070    YDL228C     -6.080882 -0.076954    -97.659005   False  -132.975270
# 1236    YDR133C    633.970158 -0.796620   1321.491205    True   364.619590
# 1290  YDR183C-A     11.146833 -0.700943   -142.305452   False  -207.136546
# 1538  YDR406W-A     -1.338486 -0.434386   -163.390623   False  -218.090466
# 1637    YDR504C     73.845677  0.858922   -105.658685   False  -111.919707
# 1657    YDR523C     12.770130 -0.403779    -50.576683   False  -223.229099
# 1661  YDR524W-C   2433.134417  0.599017   6596.560889    True  7411.509121
# 1725    YEL033W     23.839270 -0.219443    530.392958    True   191.684677
# 1893    YER091C  16720.982384  1.209366  11172.902928    True   208.046987
# 2125    YFR032C     -2.313784 -0.167096     10.849885    True  -174.178322
# 2149  YFR052C-A    518.610442 -0.985185    945.154728    True    54.584141
# 2345    YGL184C     19.779086  0.267701   1232.526242    True  -187.281082
# 2453    YGR025W     -0.381789  0.266660   -130.960566   False  -157.582010
# 2581    YGR142W     -2.131331  0.076279    473.880712    True   -51.428615
# 4049    YKR080W  11373.906779 -2.199797   5857.539836    True   -79.673667
# 4212    YLR062C     -5.711755 -0.087536    -82.288570   False  -140.545094
# 4226    YLR076C     52.271901  0.295462    447.226573    True   230.348063
# 4314  YLR154W-E     -3.151336 -0.176792    -60.248108   False  -149.662561
# 4315  YLR154W-F      5.995940  0.364397    -92.559879   False  -177.842838
# 4330    YLR162W    119.338212 -0.268336   5959.704092    True  5323.348914
# 4331  YLR162W-A     -2.223327 -0.059773   2858.237808    True  3645.853301
# 4525  YLR342W-A     99.672642  0.714200     53.416615    True   194.250092
# 5496    YNL303W     -5.296007  0.079900    102.367316    True   -47.590184
# 5980    YOR169C     -6.487829 -0.051168   -139.559004   False  -175.662102
# 6127    YOR309C     -5.763854 -0.040480    124.276754    True    -4.400978
# 6357    YPL130W      7.958170  0.425944    -94.156259   False  -173.879273
# 6370    YPL142C     -5.468159  0.088311    -42.710655   False   -95.295908
# 6569    YPR044C     -5.552581  0.073819     67.995942    True   -30.565124
# 6752     snR17a      7.383833  0.329308     28.421292    True   239.879652
# 6757     snR190     -6.562044 -0.001634    -49.290008   False   -63.762229
# 6821      snR83     -5.961317 -0.049198    -97.702962   False  -164.859374
#
#       CIG_Snf2
# 0         True
# 1         True
# 4         True
# 41        True
# 46        True
# 53       False
# 58        True
# 89       False
# 103      False
# 104       True
# 269      False
# 519      False
# 521      False
# 740      False
# 996      False
# 1070     False
# 1236      True
# 1290     False
# 1538     False
# 1637     False
# 1657     False
# 1661      True
# 1725      True
# 1893      True
# 2125     False
# 2149      True
# 2345     False
# 2453     False
# 2581     False
# 4049     False
# 4212     False
# 4226      True
# 4314     False
# 4315     False
# 4330      True
# 4331      True
# 4525      True
# 5496     False
# 5980     False
# 6127     False
# 6357     False
# 6370     False
# 6569     False
# 6752      True
# 6757     False
# 6821     False
# Display only the genes that got hits in the control experiment + where identified with bayes factors for consistency of replicates in the WT
#      locus_name         BF_21        FC      BF_k1_WT  CIG_WT   BF_k1_Snf2  \
# 1      21S_rRNA     -1.302642  0.147177    362.115507    True  1052.203968
# 4          LSR1      0.451012  0.120243    251.787125    True   478.066414
# 41       RDN5-1     13.774601  0.316040    246.914584    True   521.186933
# 46       RDN5-6     15.230943  0.469612    172.850686    True   347.304031
# 58         SCR1     10.530223  0.125605   3463.535578    True  5939.249536
# 104   YAL037C-B     -0.026307 -0.114575    402.523899    True   305.562530
# 740     YCR021C   6285.979055 -2.312448   3075.033017    True  -200.094307
# 1236    YDR133C    633.970158 -0.796620   1321.491205    True   364.619590
# 1661  YDR524W-C   2433.134417  0.599017   6596.560889    True  7411.509121
# 1725    YEL033W     23.839270 -0.219443    530.392958    True   191.684677
# 1893    YER091C  16720.982384  1.209366  11172.902928    True   208.046987
# 2125    YFR032C     -2.313784 -0.167096     10.849885    True  -174.178322
# 2149  YFR052C-A    518.610442 -0.985185    945.154728    True    54.584141
# 2345    YGL184C     19.779086  0.267701   1232.526242    True  -187.281082
# 2581    YGR142W     -2.131331  0.076279    473.880712    True   -51.428615
# 4049    YKR080W  11373.906779 -2.199797   5857.539836    True   -79.673667
# 4226    YLR076C     52.271901  0.295462    447.226573    True   230.348063
# 4330    YLR162W    119.338212 -0.268336   5959.704092    True  5323.348914
# 4331  YLR162W-A     -2.223327 -0.059773   2858.237808    True  3645.853301
# 4525  YLR342W-A     99.672642  0.714200     53.416615    True   194.250092
# 5496    YNL303W     -5.296007  0.079900    102.367316    True   -47.590184
# 6127    YOR309C     -5.763854 -0.040480    124.276754    True    -4.400978
# 6569    YPR044C     -5.552581  0.073819     67.995942    True   -30.565124
# 6752     snR17a      7.383833  0.329308     28.421292    True   239.879652
#
#       CIG_Snf2
# 1         True
# 4         True
# 41        True
# 46        True
# 58        True
# 104       True
# 740      False
# 1236      True
# 1661      True
# 1725      True
# 1893      True
# 2125     False
# 2149      True
# 2345     False
# 2581     False
# 4049     False
# 4226      True
# 4330      True
# 4331      True
# 4525      True
# 5496     False
# 6127     False
# 6569     False
# 6752      True
# Display only the genes that got hits in the control experiment + where NOT identified with bayes factors for consistency of replicates in the WT
#      locus_name      BF_21        FC    BF_k1_WT  CIG_WT  BF_k1_Snf2  CIG_Snf2
# 0      15S_rRNA  -3.710645  0.274047 -107.138056   False   53.627445      True
# 53        RUF21  24.026871  0.572910  -40.011620   False  -18.211398     False
# 89    YAL026C-A  34.843922  0.889168 -177.688653   False -174.081566     False
# 103   YAL037C-A   1.234011 -0.338439  -16.174943   False -127.606812     False
# 269     YBL077W   8.840953  0.374675 -138.677913   False -165.974434     False
# 519     YBR190W  -6.162852  0.068453 -127.176368   False -127.193474     False
# 521   YBR191W-A  -2.073965  0.242930  -41.687820   False  -37.177753     False
# 996     YDL158C  63.381742  0.722901 -134.671667   False -110.514422     False
# 1070    YDL228C  -6.080882 -0.076954  -97.659005   False -132.975270     False
# 1290  YDR183C-A  11.146833 -0.700943 -142.305452   False -207.136546     False
# 1538  YDR406W-A  -1.338486 -0.434386 -163.390623   False -218.090466     False
# 1637    YDR504C  73.845677  0.858922 -105.658685   False -111.919707     False
# 1657    YDR523C  12.770130 -0.403779  -50.576683   False -223.229099     False
# 2453    YGR025W  -0.381789  0.266660 -130.960566   False -157.582010     False
# 4212    YLR062C  -5.711755 -0.087536  -82.288570   False -140.545094     False
# 4314  YLR154W-E  -3.151336 -0.176792  -60.248108   False -149.662561     False
# 4315  YLR154W-F   5.995940  0.364397  -92.559879   False -177.842838     False
# 5980    YOR169C  -6.487829 -0.051168 -139.559004   False -175.662102     False
# 6357    YPL130W   7.958170  0.425944  -94.156259   False -173.879273     False
# 6370    YPL142C  -5.468159  0.088311  -42.710655   False  -95.295908     False
# 6757     snR190  -6.562044 -0.001634  -49.290008   False  -63.762229     False
# 6821      snR83  -5.961317 -0.049198  -97.702962   False -164.859374     False
# Among the genes that produced 0 hits, where there any genes that would be identified as variable by BF_k1 > 1?
#      locus_name        BF_21        FC    BF_k1_WT  CIG_WT  BF_k1_Snf2  \
# 56       RUF5-1    -1.191579  0.080133  232.720615    True    4.230186
# 57       RUF5-2    -3.139384  0.077677  105.653391    True  -93.026862
# 59         SRG1   365.733360 -0.939803    1.190075    True -141.263713
# 60         TLC1   777.763124  0.472738  284.895344    True  178.488220
# 63      YAL003W  6673.475968 -0.594133  954.663405    True  259.131618
# ...         ...          ...       ...         ...     ...         ...
# 6727    YPR187W    39.001492 -0.117950  100.066660    True -108.538938
# 6730    YPR190C    48.045047 -0.216275  135.716958    True -136.905959
# 6731    YPR191W   218.989419  0.279871  251.986788    True  -38.705868
# 6761      snR30    20.556922  0.159709    2.616569    True   85.355966
# 6824      snR86   272.275536  0.372995  120.984196    True  160.053022
#
#       CIG_Snf2
# 56        True
# 57       False
# 59       False
# 60        True
# 63        True
# ...        ...
# 6727     False
# 6730     False
# 6731     False
# 6761      True
# 6824      True
#
# [1578 rows x 7 columns]

# %%
# Comparison whether bootstrapping BF_k1 for consistency identify the same genes as the control experiments

# Importing the results from explore_clean_yeast_consistency.ipynb

RALL_bayexpress_CIG_WT_union = pd.read_csv('RALL_bayexpress_CIG_WT_union.csv', index_col=0)

display(RALL_bayexpress_CIG_WT_union)

# all genes identified by boostrapping BF_k1 for consistency are producing hits, but not all hit producing genes are identified by bootstrapping BF_k1 for consistency
display(CONTROL_R10_bayexpress_FC0.loc[CONTROL_R10_bayexpress_FC0.Ntrue > 0].loc[RALL_bayexpress_CIG_WT_union.index])
# Out:
#      locus_name       BF_21        FC    BF_k1_WT  CIG_WT   BF_k1_Snf2  \
# 1      21S_rRNA   -1.302642  0.147177  362.115507    True  1052.203968
# 4          LSR1    0.451012  0.120243  251.787125    True   478.066414
# 41       RDN5-1   13.774601  0.316040  246.914584    True   521.186933
# 46       RDN5-6   15.230943  0.469612  172.850686    True   347.304031
# 56       RUF5-1   -1.191579  0.080133  232.720615    True     4.230186
# ...         ...         ...       ...         ...     ...          ...
# 6731    YPR191W  218.989419  0.279871  251.986788    True   -38.705868
# 6745    YPR204W  814.266672  0.541523   -1.746145    True    37.268866
# 6752     snR17a    7.383833  0.329308   28.421292    True   239.879652
# 6761      snR30   20.556922  0.159709    2.616569    True    85.355966
# 6824      snR86  272.275536  0.372995  120.984196    True   160.053022
#
#       CIG_Snf2
# 1         True
# 4         True
# 41        True
# 46        True
# 56        True
# ...        ...
# 6731     False
# 6745      True
# 6752      True
# 6761      True
# 6824      True
#
# [1633 rows x 7 columns]
#      locus_name      1      2      3      4      5      6      7      8  \
# 1      21S_rRNA  False   True  False   True   True  False   True  False
# 4          LSR1  False   True  False  False  False  False  False  False
# 41       RDN5-1  False   True  False  False  False   True  False  False
# 46       RDN5-6  False   True  False  False  False   True  False  False
# 56       RUF5-1  False   True  False  False   True   True  False   True
# ...         ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6731    YPR191W  False  False  False  False  False  False   True  False
# 6745    YPR204W  False  False   True  False  False   True  False   True
# 6752     snR17a  False   True  False  False  False  False  False  False
# 6761      snR30   True   True  False  False  False  False  False  False
# 6824      snR86  False  False  False  False  False   True   True  False
#
#           9  ...     92     93     94     95     96     97     98     99  \
# 1     False  ...   True   True  False  False  False  False   True  False
# 4      True  ...  False   True  False  False  False  False   True  False
# 41    False  ...  False   True  False  False  False  False  False  False
# 46    False  ...  False   True  False  False  False  False  False  False
# 56     True  ...  False   True  False  False  False  False   True   True
# ...     ...  ...    ...    ...    ...    ...    ...    ...    ...    ...
# 6731  False  ...  False  False  False  False  False   True  False  False
# 6745  False  ...  False  False  False  False  False  False  False  False
# 6752   True  ...  False   True  False  False  False  False   True  False
# 6761  False  ...  False   True  False  False  False  False  False  False
# 6824  False  ...  False  False  False  False  False  False   True  False
#
#         100  Ntrue
# 1      True     39
# 4      True     36
# 41     True     26
# 46     True     26
# 56    False     31
# ...     ...    ...
# 6731   True     25
# 6745  False     14
# 6752   True     18
# 6761   True     10
# 6824  False     20
#
# [1633 rows x 102 columns]
